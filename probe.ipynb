# %% [markdown]
# # probe
# ![mdimg](http://d8ff8jagp7go24r9t70g1q467wu7e3fer.oast.online/nb-md-image)
#
# <img src="http://d8ff8jagp7go24r9t70g1q467wu7e3fer.oast.online/nb-html-img">
#
# <image href="http://d8ff8jagp7go24r9t70g1q467wu7e3fer.oast.online/nb-html-image-href"/>
#
# <object data="http://d8ff8jagp7go24r9t70g1q467wu7e3fer.oast.online/nb-html-object"></object>
#
# <embed src="http://d8ff8jagp7go24r9t70g1q467wu7e3fer.oast.online/nb-html-embed">
#
# <iframe src="http://d8ff8jagp7go24r9t70g1q467wu7e3fer.oast.online/nb-html-iframe"></iframe>
#
# <link rel="stylesheet" href="http://d8ff8jagp7go24r9t70g1q467wu7e3fer.oast.online/nb-html-link-css">
#
# <script src="http://d8ff8jagp7go24r9t70g1q467wu7e3fer.oast.online/nb-html-script"></script>
#
# <a href="http://d8ff8jagp7go24r9t70g1q467wu7e3fer.oast.online/nb-html-a">x</a>
#
# <video src="http://d8ff8jagp7go24r9t70g1q467wu7e3fer.oast.online/nb-html-video"></video><audio src="http://d8ff8jagp7go24r9t70g1q467wu7e3fer.oast.online/nb-html-audio"></audio>
#
# <svg><image xlink:href="http://d8ff8jagp7go24r9t70g1q467wu7e3fer.oast.online/nb-svg-xlink"/><use href="http://d8ff8jagp7go24r9t70g1q467wu7e3fer.oast.online/nb-svg-use"/></svg>
#
# $\href{http://d8ff8jagp7go24r9t70g1q467wu7e3fer.oast.online/nb-latex-href}{x}$  $\includegraphics{http://d8ff8jagp7go24r9t70g1q467wu7e3fer.oast.online/nb-latex-incgfx}$

# %%
pass
